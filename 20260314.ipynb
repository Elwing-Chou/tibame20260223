# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260223/blob/main/20260314.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# WIN: -headers "Origin: https://ani.gamer.com.tw" -i "" anime.mp4
#
# MAC: -headers 'Origin: https://ani.gamer.com.tw' -i '' anime.mp4
#
# cd xxx
# 可執行的程式 參數
# 1. 位置參數(放最後面, 一定會帶入的)
# 2. 告訴她參數拿來幹嗎
#    a. 短參數: -V               -短參數名 值
#    b. 長參數: --version        --長參數名 值

# %% [markdown]
# ```
# 格式
# 1. JSON格式: [], {}
# 2. 表格格式(CSV, TSV)
#    Comma-Separated Values
#    TAB-Separated Values
#
# ```

# %%
import urllib.request as req
import json
import pandas as pd

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35241&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()
# print(type(content))
content = json.loads(content)
# print(type(content))
danmu = content["data"]["danmu"]
# for d in danmu:
#     print(d["userid"], d["text"])

# pandas自訂型態: 1. DataFrame: 表格  2. ?
df = pd.DataFrame(danmu)
df.to_csv("danmu.csv", encoding="utf-8")
df.to_excel("danmu.xlsx")

# %%
f = open("test.csv", "w", encoding="utf-8")
f.write("姓名,身高\n")
f.write("Elwing,175\n")
# "A, Mid, B"
f.write('"A,Mid,B",180')
f.close()

# %%
b = 20
c = 30
"a" + str(b) + str(c)
f"a{b}{c}"
"a{}{}".format(b, c)
# Out:
# 'a2030'

# %%
import urllib.request as req
import json
import pandas as pd

def download_danmu(serial, fp):
    pat = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn={}&geo=TW%2CHK"
    url = pat.format(serial)
    print(url)
    f = req.urlopen(url)
    content = f.read()
    content = json.loads(content)
    danmu = content["data"]["danmu"]

    df = pd.DataFrame(danmu)
    df.to_csv(fp, encoding="utf-8")

download_danmu(35242, "xzxxxxx.csv")
# Out:
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35242&geo=TW%2CHK

# %% [markdown]
# ```
# HTML格式: 如何定義一塊區塊
#
# <a href="網址">
#     28
# </a>
#
# 1. 區塊名字: 決定區塊用途
# a: 超連結 img: 圖片 video: 影片
#
# 2. 區塊屬性: 決定細節
# a href="網址"
# img/video src="網址"
#
# 3. 區塊顯示文字:
#
# ```

# %%
import urllib.request as req
# BeautifulSoup4
import bs4 as bs

h = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0",
}

url = "https://ani.gamer.com.tw/animeVideo.php?sn=35241"
r = req.Request(url, headers=h)
resp = req.urlopen(r)
content = resp.read()
# 跟json.loads一樣 做出型態轉換
html = bs.BeautifulSoup(content)
# find: 找一個　find_all: 找全部(得到的型態是一個類似list型態)
# print(html.find("a"))
# print(html.find_all("a"))
for a in html.find_all("a"):
    # 找到對象區塊以後: 屬性(["href"]) 文字(.get_text())
    href = a["href"]
    if href.startswith("?sn="):
        print("下載:", href)
