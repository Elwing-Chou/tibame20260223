# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260223/blob/main/20260321.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req
import json
import pandas as pd

# name: 1 2 3...
def download_danmu(serial, fp, episode):
    pat = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn={}&geo=TW%2CHK"
    url = pat.format(serial)
    print(url)
    f = req.urlopen(url)
    content = f.read()
    content = json.loads(content)
    danmu = content["data"]["danmu"]

    df = pd.DataFrame(danmu)
    # 增加一行, 並且設定成同一個值 取行: df[行名稱]
    df["episode"] = episode
    df.to_csv(fp, encoding="utf-8")

download_danmu(35242, "xzxxxxx.csv", "10")
# Out:
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35242&geo=TW%2CHK

# %%
import os

import urllib.request as req
import bs4 as bs

h = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0",
}

# url = "https://ani.gamer.com.tw/animeVideo.php?sn=35241"
url = "https://github.com/Elwing-Chou/tibame20260223/raw/refs/heads/main/baha.html"
r = req.Request(url, headers=h)
resp = req.urlopen(r)
content = resp.read()
html = bs.BeautifulSoup(content)

save_dir = "baha"
# 新創資料夾: 如果資料夾不存在, make起來
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

for a in html.find_all("a"):
    # 找到對象區塊以後: 屬性(["href"]) 文字(.get_text())
    href = a["href"]
    if href.startswith("?sn="):
        print("下載:", href)
        sn = href.replace("?sn=", "")
        episode = a.get_text()
        print("集數:", episode)
        fp = save_dir + "/" + sn + ".csv"
        print("儲存位置:", fp)
        download_danmu(sn, fp, episode)
# Out:
# 下載: ?sn=35241
# 集數: 1
# 儲存位置: baha/35241.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35241&geo=TW%2CHK
# 下載: ?sn=35242
# 集數: 2
# 儲存位置: baha/35242.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35242&geo=TW%2CHK
# 下載: ?sn=35243
# 集數: 3
# 儲存位置: baha/35243.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35243&geo=TW%2CHK
# 下載: ?sn=35244
# 集數: 4
# 儲存位置: baha/35244.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35244&geo=TW%2CHK
# 下載: ?sn=35445
# 集數: 5
# 儲存位置: baha/35445.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35445&geo=TW%2CHK
# 下載: ?sn=35446
# 集數: 6
# 儲存位置: baha/35446.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35446&geo=TW%2CHK
# 下載: ?sn=35447
# 集數: 7
# 儲存位置: baha/35447.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35447&geo=TW%2CHK
# 下載: ?sn=35660
# 集數: 8
# 儲存位置: baha/35660.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35660&geo=TW%2CHK
# 下載: ?sn=35781
# 集數: 9
# 儲存位置: baha/35781.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35781&geo=TW%2CHK
# 下載: ?sn=35845
# 集數: 10
# 儲存位置: baha/35845.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35845&geo=TW%2CHK
# 下載: ?sn=36046
# 集數: 11
# 儲存位置: baha/36046.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36046&geo=TW%2CHK
# 下載: ?sn=36128
# 集數: 12
# 儲存位置: baha/36128.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36128&geo=TW%2CHK
# 下載: ?sn=36196
# 集數: 13
# 儲存位置: baha/36196.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36196&geo=TW%2CHK
# 下載: ?sn=36260
# 集數: 14
# 儲存位置: baha/36260.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36260&geo=TW%2CHK
# 下載: ?sn=36371
# 集數: 15
# 儲存位置: baha/36371.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36371&geo=TW%2CHK
# 下載: ?sn=36553
# 集數: 16
# 儲存位置: baha/36553.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36553&geo=TW%2CHK
# 下載: ?sn=36554
# 集數: 17
# 儲存位置: baha/36554.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36554&geo=TW%2CHK
# 下載: ?sn=36861
# 集數: 18
# 儲存位置: baha/36861.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36861&geo=TW%2CHK
# 下載: ?sn=36862
# 集數: 19
# 儲存位置: baha/36862.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36862&geo=TW%2CHK
# 下載: ?sn=36991
# 集數: 20
# 儲存位置: baha/36991.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36991&geo=TW%2CHK
# 下載: ?sn=37034
# 集數: 21
# 儲存位置: baha/37034.csv
# https://api.gamer.com.tw/anime/v1/danmu.php?videoSn