# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260223/blob/main/ximen20260325.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# list[key]
scores = [80, 60, 70, 50]

count = 0
i = 0
while i < len(scores):
    s = scores[i]
    if s >= 60:
        count = count + 1
    i = i + 1
print(count)
# Out:
# 3
