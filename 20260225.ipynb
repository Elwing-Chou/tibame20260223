# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260223/blob/main/20260225.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_leap_year(year):
    if year % 400 == 0:
        return True
    elif year % 100 == 0:
        return False
    elif year % 4 == 0:
        return True
    else:
        return False

# %%
# 判斷年月日是否合理(先不用閏年)
# 123: 23(%100) 1(//100)
d = 20240229
day = d % 100
remain = d // 100
month = remain % 100
year = remain // 100
print(year, month, day)
# 確認是否合理
if year >= 1:
    if 1 <= month <= 12:
        day_per_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
        day_max = day_per_month[month-1]
        # if month == 2 and is_leap_year(year) == True
        if month == 2 and is_leap_year(year):
            day_max = day_max + 1
        if 1 <= day <= day_max:
            print("VALID")
        else:
            print("day invalid")
    else:
        print("month invalid")
else:
    print("year invalid")
# Out:
# 2024 2 29
# VALID

# %%
#
def is_date_valid(d):
    day = d % 100
    remain = d // 100
    month = remain % 100
    year = remain // 100
    # print(year, month, day)
    # 確認是否合理
    if year >= 1:
        if 1 <= month <= 12:
            day_per_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
            day_max = day_per_month[month-1]
            # if month == 2 and is_leap_year(year) == True
            if month == 2 and is_leap_year(year):
                day_max = day_max + 1
            if 1 <= day <= day_max:
                return True
    return False

is_date_valid(20240229)
# Out:
# True

# %%
# 固定幾次的迴圈
i = 0
while i < 10:
    print(10-i)
    i = i + 1

for i in range(10):
    print(10-i)

# %%
# 不限次數的迴圈
# 0:+ 1:-
import random
count = 0
while True:
    coin = random.randint(0, 1)
    print(coin)
    if coin == 0:
        count = count + 1
    if count == 3:
        break

# %%
# 4499(20241001) 往後印出10個完全平方日
count = 0
start = 4499
while True:
    d = start ** 2
    if is_date_valid(d):
        print(d)
        count = count + 1
    if count == 10:
        break
    start = start + 1

# %%
def get_fully_squared_2(start=4499, limit=10):
    count = 0
    result = []
    while True:
        d = start ** 2
        if is_date_valid(d):
            result.append(d)
            count = count + 1
        if count == limit:
            break
        start = start + 1
    return result

get_fully_squared_2(limit=20)
# Out:
# [20241001,
#  20720704,
#  20930625,
#  21150801,
#  21390625,
#  21520321,
#  21641104,
#  21650409,
#  21790224,
#  21921124,
#  22071204,
#  22080601,
#  22231225,
#  22420225,
#  22591009,
#  22600516,
#  22800625,
#  23011209,
#  23020804,
#  23030401]
