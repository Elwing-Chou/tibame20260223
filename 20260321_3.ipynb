# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260223/blob/main/20260321_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install uvicorn[standard]
# pip install fastapi
# uvicorn 你的py名:app

# 看文件: docs redoc
# http://127.0.0.1:8000/test/202
# http://127.0.0.1:8000/test/202?q=elwing&b=100

# http://127.0.0.1:8000/docs
# http://127.0.0.1:8000/redoc
from fastapi import FastAPI
from typing import Optional

app = FastAPI()


@app.get("/")
def root():
    return {"message": "Hello World"}

# fastapi參數: 1. 必帶user_id  2. 選用: q b
@app.get("/test/{user_id}") # 指定 api 路徑 (get方法)
def test(user_id:int, q:str ="default", b:int=20):
    return {"user_id":user_id, "q":q, "b":b}

@app.get("/users/{user_id}") # 指定 api 路徑 (get方法)
def read_user(user_id:int, q:Optional[str]=None):
    return {"user_id":user_id, "q":q}

# %%
# python with sql
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey
from sqlalchemy import inspect
from sqlalchemy.sql import text


metadata = MetaData()
books = Table('book', metadata,
  Column('id', Integer, primary_key=True),
  Column('title', String),
  Column('primary_author', String),
)

engine = create_engine('sqlite:///bookstore.db')
metadata.create_all(engine)

# insert
with engine.connect() as connection:
    title = "Best Journey"
    primary_author = "Elwing"

    statement = text("""INSERT INTO book(title, primary_author) VALUES(:title, :primary_author)""")

    connection.execute(statement.params(title=title, primary_author=primary_author))
    connection.commit()

    result = connection.execute(text('SELECT * FROM book'))
    for row in result:
        print(row)

# %%
import urllib.request as req

url = "https://ngrok給你的/test/2000?q=abc&b=123"
resp = req.urlopen(url)
resp.read()
