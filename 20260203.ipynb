# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260223/blob/main/20260203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. jupyter notebook的文字是使用markdown語法
# 2. 完整python檔案 .py結尾, jupyter notebook這個python工具產生的是 .ipynb結尾
# 3. colab基本就是一個線上版本的jupyter notebook
# 4. 文字還支援一種特殊語法: latex math
#
# $ Area = \frac{1}{2} \pi {R_1}^2 $
